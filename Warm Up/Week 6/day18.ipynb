# %%
import pandas as pd

# %%
df1 = pd.read_csv('student.csv')
df2 = pd.read_csv('test_data.csv')

# %%
print(f'shape df1: {df1.shape}')
print(f'shape df2: {df2.shape}')
# Out:
# shape df1: (307, 16)
# shape df2: (30, 6)

# %%
df_merge = pd.merge(df1, df2, on='id', how='inner')
df_merge.head()
# Out:
#    id            name_x               nationality               city_x  \
# 0   1    Joshua Lonaker  United States of America        Santa Clarita
# 1   2     Dakota Blanco  United States of America              Oakland
# 2   3   Natasha Yarusso  United States of America        Castro Valley
# 3   4    Brooke Cazares                    Brazil  São José dos Campos
# 4   5  Rochelle Johnson  United States of America         Indianapolis
#
#    latitude  longitude gender_x  ethnic.group  age_x  english.grade  ...  \
# 0     34.39    -118.54        M           NaN     22            2.9  ...
# 1     37.80    -122.27        F           NaN     22            3.9  ...
# 2     37.69    -122.09        F           NaN     20            3.3  ...
# 3    -23.18     -45.88        F           NaN     21            3.7  ...
# 4     39.77     -86.16        F           NaN     21            3.4  ...
#
#    sciences.grade  language.grade  portfolio.rating  coverletter.rating  \
# ...

# %%
print(f'shape merged: {df_merge.shape}')
print(f'shape df1: {df1.shape}')
print(f'shape df2: {df2.shape}')
# Out:
# shape merged: (30, 21)
# shape df1: (307, 16)
# shape df2: (30, 6)

# %%
df_pivot1 = df1.pivot_table(values='math.grade', index='nationality', columns='gender', aggfunc='sum')

# %%
df_pivot1.head()
# Out:
# gender          F     M  other
# nationality
# Bangladesh    3.9   NaN    NaN
# Brazil       19.6  10.8    NaN
# Canada        9.6   8.5    3.0
# Chile         NaN   3.7    NaN
# China        18.5  30.7    NaN

# %%
df_pivot2 = df1.pivot_table(values='english.grade', index='ethnic.group', columns='gender', aggfunc='mean')
df_pivot2
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# bài 3

# %%
data = df1.pivot_table(values='sciences.grade', index='gender', aggfunc='mean')
data.plot(kind='bar')
# Out:
# <Axes: xlabel='gender'>

# %%
df1['age'].hist()
# Out:
# <Axes: >

# %%
import seaborn as sns

# %%
data2 = df1[['english.grade', 'math.grade', 'sciences.grade', 'language.grade']]

# %%
sns.heatmap(data2.corr())
# Out:
# <Axes: >
